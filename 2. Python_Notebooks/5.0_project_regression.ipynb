# %% [markdown]
# # 0. Introduction

# %%
#refers to my notebook with all my functions and imports
# %run ./2.Cheatsheet_functions_python.ipynb

data = pd.read_csv('../1.Data/regression_data_clean.csv')

# %%
data.head()
# Out:
#            id      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  10/13/14         3       1.00         1180      5650     1.0
# 1  6414100192   12/9/14         3       2.25         2570      7242     2.0
# 2  5631500400   2/25/15         2       1.00          770     10000     1.0
# 3  2487200875   12/9/14         4       3.00         1960      5000     1.0
# 4  1954400510   2/18/15         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000

# %%
data.shape
# Out:
# (21597, 21)

# %% [markdown]
# # 1. Exploratory data analysis (EDA)

# %%
display_missing(data)
# Out:
# Done checking for missing values

# %%
cols_dtypes(data)
# Out:
#    catergoricals or mixed     nuermicals booleans     floats integers
# 0                    date             id     None  bathrooms     None
# 1                    None       bedrooms     None     floors     None
# 2                    None      bathrooms     None        lat     None
# 3                    None    sqft_living     None       long     None
# 4                    None       sqft_lot     None       None     None
# 5                    None         floors     None       None     None
# 6                    None     waterfront     None       None     None
# 7                    None           view     None       None     None
# 8                    None      condition     None       None     None
# 9                    None          grade     None       None     None
# 10                   None     sqft_above     None       None     None
# 11                   None  sqft_basement     None       None     None
# 12                   None       yr_built     None       None     None
# 13                   None   yr_renovated     None       None     None
# 14                   None        zipcode     None       None     None
# 15                   None            lat     None       None     None
# 16                   None           long     None       None     None
# 17                   None  sqft_living15     None       None     None
# 18                   None     sqft_lot15     None       None     None
# 19                   None          price     None       None     None

# %%
nums= data.select_dtypes(np.number)

# %%
fig, ax = plt.subplots(figsize = (50, 50))

sns.heatmap(nums.corr().round(2),vmin=-1, vmax=1, center=0, annot = True, annot_kws = {'size':20},square=True,
cmap='seismic')

ax.tick_params(axis='x', labelsize = 25 )
ax.tick_params(axis='y', labelsize = 25 )
plt.show()

# %% [markdown]
# # 2. Feature engineering

# %% [markdown]
# # 3. Models

# %% [markdown]
# # 4. Validation and Conclusion
